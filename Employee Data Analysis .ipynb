# %% [markdown]
# **Importing necessary libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading Data sets and printing first 15 values**

# %%
df = pd.read_csv('D:\Ostad DS Course\Data Science\Data set/employees.csv')
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# **Info about data.
# axis=0 == ROW;
# axis=1 == COLUMN;
# This data set has 1000 rows and 8 columns**

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# **Describe method applies a basic statistical operations on data point for the numerical value.
# Here 'NaN- Not a Number' are automatically skiped and it gives a good info about distribution on the data**

# %%
df.describe() #df.describe(include='all')
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %% [markdown]
# **This operations shows all the data type**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# **Converting 'Start Date' into "datetime()" format;
# changes are made from object type to DateTime format**

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])
df
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# **This method extracts all the UNIQUE VALUES from all column of the data set**

# %%
df.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      720
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %% [markdown]
# **Handling missing values from data set;
# the reault will show all the missing values in data set**

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %% [markdown]
# **Replace " missing value / null value " by empty string**

# %%
df['Gender'].fillna('No Gender', inplace= True)
df
# Out:
#     First Name     Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas       Male 1996-03-31         6:53 AM   61933    4.170
# 2        Maria     Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry       Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry       Male 1998-01-24         4:47 PM  101004    1.389
# ..         ...        ...        ...             ...     ...      ...
# 995      Henry  No Gender 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip       Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell       Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry       Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert       Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %% [markdown]
# **After replacing the missing values of Gender column by empty string, we check again if there is any missing values or not**

# %%
df.isnull().sum()
# Out:
# First Name           67
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management    67
# Team                 43
# dtype: int64

# %% [markdown]
# **Replacing all the missing values of Senior Management Column by calculating the MODE of that individual column**

# %%
mode = df['Senior Management'].mode().values[0]

df['Senior Management'] = df['Senior Management'].replace(np.nan, mode)

# %%
df
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       1 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas       1 1996-03-31         6:53 AM   61933    4.170
# 2        Maria       0 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry       1 2005-03-04         1:00 PM  138705    9.340
# 4        Larry       1 1998-01-24         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry       2 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip       1 1984-01-31         6:30 AM   42392   19.675
# 997    Russell       1 2013-05-20        12:39 PM   96914    1.421
# 998      Larry       1 2013-04-20         4:45 PM   60500   11.985
# 999     Albert       1 2012-05-15         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# ...

# %% [markdown]
# **So, after being replaced by MODE value from missing, we checked if there is anything as missing values or not**

# %%
df.isnull().sum()
# Out:
# First Name           67
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management     0
# Team                 43
# dtype: int64

# %% [markdown]
# ***Now we have to work on "First Name" and "Team" column.
# As these are Arbitrary Data, so we cant fill it.
# We have drop these these missing rows***

# %%
df1 = df.dropna(axis=0, how='any')

print(df1.isnull().sum())
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %% [markdown]
# **We checked the whole data set after dropping all the missing / null values from the data set.     Before the data was " 1000,8 " and now data is " 899, 8"**

# %%
df1.shape
# Out:
# (899, 8)

# %% [markdown]
# **Here we operated ENCODING OPERATION for the Gender value; Because categorical data can not be encoded untils its converting into NUMERICAL DATA**

# %%
from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df1
# Out:
#     First Name     Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male 1993-08-06        12:42 PM   97308    6.945
# 2        Maria     Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry       Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry       Male 1998-01-24         4:47 PM  101004    1.389
# 5       Dennis       Male 1987-04-18         1:35 AM  115163   10.125
# ..         ...        ...        ...             ...     ...      ...
# 995      Henry  No Gender 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip       Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell       Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry       Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert       Male 2012-05-15         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# **Visualizing data (Gender), as uni-variate analysis method, Method = HistPlot**

# %%
sns.histplot(x='Salary', data=df) #binwidth=5000

plt.figure(figsize=(15, 4))
plt.show()

# %% [markdown]
# **Visualizing data (Gender), as bi-variate analysis method, Method = BoxPlot**

# %%
sns.boxplot(x='Salary', y='Team', data=df)

plt.figure(figsize=(15, 4))
plt.show()

# %% [markdown]
# **Visualizing data (Gender AND Team), as bi-variate analysis method, Method = ScatterPlot**

# %%
sns.scatterplot( x="Salary", y='Team', data=df, hue='Gender', size='Bonus %')

plt.legend(bbox_to_anchor=(1, 1), loc=2)

# %% [markdown]
# **For multivariate analysis, we can use pairplot()method of the seaborn module**

# %%
sns.pairplot(df, hue='Gender', height=2)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
